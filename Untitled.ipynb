# %%
#Reproduction de la figure 2 Lejeune et Al.(2003)
import matplotlib.pyplot as plt

figure = plt.figure(figsize = (10,8))
plt.plot([0,0], label="instable")
plt.xlim(0,1.3)
plt.ylim(0,1.3)
plt.xlabel("mu")
plt.ylabel("rho")
plt.title("Figure 2")
plt.legend()
plt.show()
